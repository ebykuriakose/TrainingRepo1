# %% [markdown]
# ![IPORT-chart.jpg](attachment:IPORT-chart.jpg)
# # Heading 1
# ## Section 1
#         This is heading 1 section 1 comment for the exercise.

# %%
#Lets calculate the Area of a triangle
Base = 6
Height = 8

print("Base of the Traiange = ", Base, "and the Height = ", Height)
print("The data type for Base is ", type(Base), " and the data type for Height is ", type(Height))
Area = 1/2*Base*Height

print("Area of the triangle = ", Area)
print("The data type for Area is ", type(Area))
# Out:
# Base of the Traiange =  6 and the Height =  8
# The data type for Base is  <class 'int'>  and the data type for Height is  <class 'int'>
# Area of the triangle =  24.0
# The data type for Area is  <class 'float'>

# %%
#in this exercise we will ask the user for input for his/her name
YourName = input("Enter your name: ")
print("The area of the triangle was calculated by ", YourName)

#Now lets ask the user to enter his/her age
YourAge = input("Enter your Age: ")
print("Your age is ", YourAge, " And the data type for the age is ", type(YourAge))
# Out:
# Enter your name: Eby
# The area of the triangle was calculated by  Eby
# Enter your Age: 25
# Your age is  25  And the data type for the age is  <class 'str'>
